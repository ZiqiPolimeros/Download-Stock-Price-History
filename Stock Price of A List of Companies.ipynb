# %%
import requests
import yfinance as yf

import matplotlib.pyplot as plt
import pandas as pd

# %%
# get company stock ticker

def getTicker(company_name):
    yfinance = "https://query2.finance.yahoo.com/v1/finance/search"
    user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'
    params = {"q": company_name, "quotes_count": 1, "country": "United States"}

    res = requests.get(url=yfinance, params=params, headers={'User-Agent': user_agent})
    data = res.json()

    company_code = data['quotes'][0]['symbol']
    return company_code

# %%
# this is given by Professor
company_names = ["JPMorgan Chase & Co.", 
                 "Bank of America Corporation", 
                 "Citigroup Inc.",
                 "Wells Fargo & Company",
                 "The Toronto-Dominion Bank",
                 "UBS Group AG",
                 "Credit Suisse",
                 "BMO",
                 "NatWest Group plc",
                 "U.S. Bancorp",
                 "Truist Financial Corporation",
                 "The PNC Financial Services Group, Inc.",
                 "SVB",
                 "Signature Bank",
                 "First Republic Bank",
                 "M&T Bank Corporation",
                 "HDFC Bank Limited",
                 "Citizens Financial Group, Inc.",
                 "New York Community Bancorp",
                 "PacWest Bancorp"]

# %%
Symbol = [getTicker(name) for name in company_names]

# %%
Symbol
# Out:
# ['JPM',
#  'BAC',
#  'C',
#  'WFC',
#  'TD.TO',
#  'UBS',
#  'USOI',
#  'BMO',
#  'NWG',
#  'USB',
#  'TFC',
#  'PNC',
#  'SIVBQ',
#  'SBNY',
#  'FRCB',
#  'MTB',
#  'HDB',
#  'CFG',
#  'NYCB',
#  'PACW']

# %%
# Get the data for the stocklist
data = yf.download(Symbol,'2019-09-01','2020-12-31')
# Out:
# [*********************100%***********************]  20 of 20 completed

# %%
data
# Out:
#             Adj Close                                                          \
#                   BAC        BMO          C        CFG        FRCB        HDB
# Date
# 2019-09-03  24.599083  57.662560  55.306320  27.826578   86.101562  51.191498
# 2019-09-04  24.999218  57.985844  56.056301  28.131157   86.629547  51.352364
# 2019-09-05  25.740681  58.947166  57.852753  28.934908   87.675766  50.489506
# 2019-09-06  25.383675  59.474632  57.530087  28.884150   87.206459  50.850250
# 2019-09-09  26.207525  60.291325  59.989307  30.220900   89.073959  50.860001
# ...               ...        ...        ...        ...         ...        ...
# 2020-12-23  28.399292  68.559494  55.537098  32.005123  138.538681  67.342094
# 2020-12-24  28.314234  68.731552  55.345211  31.787891  138.607727  67.810089
# 2020-12-28  28.474899  68.740593  55.856907  31.778837  140.718430  68.833817
# 2020-12-29  28.361488  68.668159  55.655891  31.570663  140.452118  68.950813
# ...

# %%
"""
Can I use a for loop here to get stock price of all companies?
"""

df = pd.DataFrame
for s in Symbol: 
    # concat all the data in rows
    df = pd.concat([df,yf.download(s,'2019-09-01','2020-12-31')], ignore_index=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8172/2159273771.py in <module>
#       6 for s in Symbol:
#       7     # concat all the data in rows
# ----> 8     df = pd.concat([df,yf.download(s,'2019-09-01','2020-12-31')], ignore_index=True)
#       9
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# ...

# %%
# download stock price history for one company

userInput = Symbol[0]
# Get the data for the stocklist
user_data0 = yf.download(userInput,'2019-09-01','2020-12-31')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
list(user_data0)
# Out:
# ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# %%
Symbol[0]
# Out:
# 'JPM'

# %%
data[list(user_data0)[0]].iloc[:,0]
# Out:
# Date
# 2019-09-03    27.209999
# 2019-09-04    27.320000
# 2019-09-05    27.850000
# 2019-09-06    28.020000
# 2019-09-09    28.000000
#                 ...
# 2020-12-23    29.389999
# 2020-12-24    30.270000
# 2020-12-28    30.230000
# 2020-12-29    30.170000
# 2020-12-30    30.000000
# Name: BAC, Length: 341, dtype: float64

# %%
"""
when I test them independently, they worked fine, but once I put them in a for loop, there's a problem
"""

df = pd.DataFrame()
for i in list(len(Symbol)):
    for j in list(len(user_data0)):
        # concat two series in columns 
        df = pd.concat([data[list(user_data0)[j]].iloc[:,i], data[list(user_data0)[j]].iloc[:,i+20]], axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8172/507013916.py in <module>
#       4
#       5 df = pd.DataFrame()
# ----> 6 for i in list(len(Symbol)):
#       7     for j in list(len(user_data0)):
#       8         # concat two series in columns
#
# TypeError: 'int' object is not iterable
